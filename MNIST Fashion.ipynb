# %%
import keras
from keras.datasets import fashion_mnist
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D
from keras.models import Sequential

# %%
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()

# %%
x_train = x_train/255
x_test = x_test/255

# %%
model= Sequential()
model.add(Conv2D(64,3,activation='relu',input_shape =(28,28,1)))
model.add(Conv2D(128,3,activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)
y_train = keras.utils.to_categorical(y_train,10)
y_test = keras.utils.to_categorical(y_test,10)

# %%
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
cnn_classifier=model.fit(x_train,y_train,epochs=6,validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/6
# 48000/48000 [==============================] - 19s 398us/step - loss: 0.3766 - acc: 0.8646 - val_loss: 0.2954 - val_acc: 0.8955: 9s - loss: 0.4545 - - ETA: 9s - loss: 0.443 - ETA: 5s - loss: 0.4139 - acc: 0. - E - ETA: 0s - loss: 0.3802 - a
# Epoch 2/6
# 48000/48000 [==============================] - 18s 378us/step - loss: 0.2459 - acc: 0.9115 - val_loss: 0.2796 - val_acc: 0.896391 - ETA: 7s - loss: - ETA: 6s - loss: 0.2492 - acc:  - ETA: 6s  - ETA: 4s - loss: 0.2474 - acc: 0 - ET
# Epoch 3/6
# 48000/48000 [==============================] - 19s 388us/step - loss: 0.2093 - acc: 0.9261 - val_loss: 0.2386 - val_acc: 0.91688s - loss: 0.2121 - ac - - ETA: 6s - loss: 0.2111 - acc - ETA: 5s - loss: 0.2108 - acc - ETA: 5s - loss: 0.2109 - acc: 0  - ETA: 0s - loss: 0.2092 - a
# Epoch 4/6
# 48000/48000 [==============================] - 19s 398us/step - loss: 0.1863 - acc: 0.9338 - val_loss: 0.2493 - val_acc: 0.9167
# Epoch 5/6
# 48000/48000 [==============================] - 18s 379us/step - loss: 0.1678 - acc: 0.9413 - val_loss: 0.2334 - val_acc: 0.91938s - loss: 0.15 - ETA: 5s - loss: 0.1612 - acc - ETA: 5s - loss: 0.162 - ETA: 4s - loss: 0.1644 - acc: 0.94 - ETA: 4s - loss: 0.16 - ETA: 0s - loss: 0.1
# Epoch 6/6
# 48000/48000 [==============================] - 18s 383us/step - loss: 0.1561 - acc: 0.9462 - val_loss: 0.2635 - val_acc: 0.91653s - loss: 0.1 - ETA: 2s - loss: 0.1560 - - ETA: 1s

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(cnn_classifier.history['acc'])
plt.plot(cnn_classifier.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(cnn_classifier.history['loss'])
plt.plot(cnn_classifier.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
