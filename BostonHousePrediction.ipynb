# %%
import pandas as pd
from sklearn.datasets import load_boston

# %%
boston = load_boston()
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
input_df = pd.DataFrame(data= boston.data,columns=boston.feature_names)

# %%
input_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
input_df.plot.hist(subplots=True,figsize=(8,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DAD3EBB2E8>,
# ...
#       dtype=object)

# %%
input_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
y= boston.target
x= pd.get_dummies(input_df,columns=['RAD'])

# %%
x
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS    TAX  PTRATIO  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  296.0     15.3
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  242.0     17.8
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  242.0     17.8
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  222.0     18.7
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  222.0     18.7
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  222.0     18.7
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  311.0     15.2
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  311.0     15.2
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  311.0     15.2
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  311.0     15.2
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467  311.0     15.2
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.3,random_state=111)

# %%
predictor = LinearRegression()

# %%
predictor.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predictor.coef_
# Out:
# array([-1.14779186e-01,  5.95804129e-02,  3.50891735e-02,  1.35721059e+00,
#        -1.40124890e+01,  3.36763694e+00, -9.32776957e-03, -1.50973207e+00,
#        -8.37322672e-03, -9.26616025e-01,  9.67747535e-03, -5.63187819e-01,
#        -2.89415415e+00, -1.36248649e+00,  1.22237154e+00, -1.02944091e+00,
#        -7.40958131e-01, -1.92012190e+00,  2.97544530e+00,  4.47036541e-01,
#         3.30230820e+00])

# %%
y_pred = predictor.predict(X_test)

# %%
predictor.score(X_test,Y_test)
# Out:
# 0.7212598719952403

# %%
predictor.score(X_train,Y_train)
# Out:
# 0.7551090589851017

# %%
import matplotlib.pyplot as plt

# %%
coeffs =  predictor.coef_

features = X_train.columns
for i,coef in enumerate(coeffs):
    print(features[i],coef)
# Out:
# CRIM -0.11477918576365315
# ZN 0.05958041286408682
# INDUS 0.03508917345741603
# CHAS 1.357210587450352
# NOX -14.012488971326892
# RM 3.367636940969474
# AGE -0.009327769565547343
# DIS -1.5097320686155336
# TAX -0.00837322672240949
# PTRATIO -0.9266160254926422
# B 0.009677475352748854
# LSTAT -0.5631878192723146
# RAD_1.0 -2.894154153257592
# RAD_2.0 -1.3624864921950284
# RAD_3.0 1.2223715411192408
# RAD_4.0 -1.0294409112187528
# RAD_5.0 -0.7409581306014343
# RAD_6.0 -1.920121896698538
# RAD_7.0 2.97544529733519
# RAD_8.0 0.4470365410274374
# RAD_24.0 3.3023082044895102
